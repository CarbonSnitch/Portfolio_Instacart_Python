# %% [markdown]
# # Contents
#
# - importing merged ords and prods
#
# - removing unnamed column in ords
#
# - merging ords with prods
#
# - checking merge
#
# - exporting as pkl

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.

# %%
#Creating Path
path = r"C:\Users\ryani\Desktop\Data Analyst COURSE\Data Immersion\06-2025 E4 INSTACART Py"

# %%
#Importing merged ords prods
df_ord_prod_comb = pd.read_pickle (os.path.join (path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_ord_prod_comb.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %% [markdown]
# # Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).

# %%
df_ord_prod_comb.shape
# Out:
# (32434489, 11)

# %% [markdown]
# Yes, same

# %% [markdown]
# # Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %%
#Importing products
df_prods = pd.read_csv (os.path.join (path, '02 Data', 'Prepared Data', 'products_cleaned.csv'))
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#Remove Unnamed column
df_prods= df_prods.drop ('Unnamed: 0', axis=1)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# #Merging the two datasets
# df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)
# df_merged_large.head()

# %%
# Merging on product_id, inner join
df_ords_prods_merge = df_ord_prod_comb.merge(df_prods, on = 'product_id', indicator = 'merge_indicator')
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered _merge                             product_name  aisle_id  \
# ...

# %%
df_prods.shape
# Out:
# (49672, 5)

# %% [markdown]
# # Confirm the results of the merge using the merge flag.

# %%
df_ords_prods_merge['merge_indicator'].value_counts()
# Out:
# merge_indicator
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# Less than the original rows, not all have merged

# %%
#Outer join to see what did NOT merge
df_ords_prods_outer = df_ord_prod_comb.merge(df_prods, on = 'product_id', how='outer', indicator = 'merge_indicator')

# %%
df_ords_prods_outer['merge_indicator'].value_counts()
# Out:
# merge_indicator
# both          32404859
# left_only        30200
# right_only          11
# Name: count, dtype: int64

# %%
df_ords_prods_outer
# Out:
#            order_id   user_id  order_number  orders_day_of_week  \
# 0         3139998.0     138.0          28.0                 6.0
# 1         1977647.0     138.0          30.0                 6.0
# 2          389851.0     709.0           2.0                 0.0
# 3          652770.0     764.0           1.0                 3.0
# 4         1813452.0     764.0           3.0                 4.0
# ...             ...       ...           ...                 ...
# 32435065  1788356.0  200215.0           2.0                 0.0
# 32435066  3401313.0  200377.0           1.0                 4.0
# 32435067   809510.0  200873.0           5.0                 3.0
# 32435068  2359893.0  200873.0           9.0                 3.0
# 32435069  2385091.0  205926.0          11.0                 1.0
#
#           order_hour_of_day  days_since_prior_order new_customer  product_id  \
# 0                      11.0                     3.0        False           1
# ...

# %% [markdown]
# Looks like 11 products have never been ordered and 30200 orders dont have a product id?

# %%
#Exporting as pickle as likely large file
df_ords_prods_merge.to_pickle (os.path.join (path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))
