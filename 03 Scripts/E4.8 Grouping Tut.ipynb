# %% [markdown]
# # Contents
#
# - import ords_prods
#
# - finding most loyal customers
#
# - ascerning whether more money in spent in diff loyalty groups (Answer = no)
#
# - adding Low spender / High spender flags
#
# - adding customer ordering frequency flags
#
# - exporting df as pkl with new flags

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r"C:\Users\ryani\Desktop\Data Analyst COURSE\Data Immersion\06-2025 E4 INSTACART Py"

# %%
df_ords_prods_merge = pd.read_pickle (os.path.join (path, '02 Data', 'Prepared Data', 'ords_prods_merge_req.pkl'))

# %%
#Make a new df with 1 million rows
df = df_ords_prods_merge[:1000000]
df
# Out:
#          order_id  user_id  order_number  orders_day_of_week  \
# 0       2539329.0      1.0             1                   2
# 1       2539329.0      1.0             1                   2
# 2       2539329.0      1.0             1                   2
# 3       2539329.0      1.0             1                   2
# 4       2539329.0      1.0             1                   2
# ...           ...      ...           ...                 ...
# 999995  2789027.0   6474.0             2                   3
# 999996  2789027.0   6474.0             2                   3
# 999997  2789027.0   6474.0             2                   3
# 999998  2789027.0   6474.0             2                   3
# 999999  2789027.0   6474.0             2                   3
#
#         order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                       8                     NaN          True       196.0
# 1                       8                     NaN          True     14084.0
# ...

# %%
df.shape
# Out:
# (1000000, 20)

# %%
#Grouping Data with pandas
df.groupby('product_name')

# %% [markdown]
# To recap, you should always use the groupby() function as part of a series of steps, namely, the following:
#
# Split the data into groups based on some criteria.
#
# Apply a function to each group separately.
#
# Combine the results into a dataframe or alternative data structure or create a new column in the current dataframe.

# %% [markdown]
# Performing a Single Aggregation
#
#
# Split the data into groups based on “department_id.”
# Apply the agg() function to each group to obtain the mean values for the “order_number” column.

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %%
# Transforming data so that we can find the most loyal customers. This uses numpy.

df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
df_ords_prods_merge.head(10)
# Out:
# C:\Users\ryani\AppData\Local\Temp\ipykernel_21148\2010738211.py:3: FutureWarning: The provided callable <function max at 0x000001CA994E2B60> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0             1                   2                  8
# 1  2539329.0      1.0             1                   2                  8
# 2  2539329.0      1.0             1                   2                  8
# 3  2539329.0      1.0             1                   2                  8
# 4  2539329.0      1.0             1                   2                  8
# 5  2398795.0      1.0             2                   3                  7
# ...

# %%
pd.options.display.max_rows = None

# %%
#Remove the default 10-rows-only table output with above code
df_ords_prods_merge.head(100)
# Out:
#      order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329.0      1.0             1                   2                  8
# 1   2539329.0      1.0             1                   2                  8
# 2   2539329.0      1.0             1                   2                  8
# 3   2539329.0      1.0             1                   2                  8
# 4   2539329.0      1.0             1                   2                  8
# 5   2398795.0      1.0             2                   3                  7
# 6   2398795.0      1.0             2                   3                  7
# 7   2398795.0      1.0             2                   3                  7
# 8   2398795.0      1.0             2                   3                  7
# 9   2398795.0      1.0             2                   3                  7
# 10  2398795.0      1.0             2                   3                  7
# ...

# %%
#Now need to assign the loyalty flags to the df
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#Now to count loyal customers
df_ords_prods_merge.value_counts('loyalty_flag')
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
df_ords_prods_merge ['loyalty_flag'].value_counts(dropna=False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
df_ords_prods_merge.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0             1                   2                  8
# 1  2539329.0      1.0             1                   2                  8
# 2  2539329.0      1.0             1                   2                  8
# 3  2539329.0      1.0             1                   2                  8
# 4  2539329.0      1.0             1                   2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True       196.0                  1
# 1                     NaN          True     14084.0                  2
# 2                     NaN          True     12427.0                  3
# 3                     NaN          True     26088.0                  4
# 4                     NaN          True     26405.0                  5
#
#    reordered  ... aisle_id department_id  prices  merge_indicator  \
# ...

# %%
#Only Head for specific columns
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       1.0      New customer             1
# 1       1.0      New customer             1
# 2       1.0      New customer             1
# 3       1.0      New customer             1
# 4       1.0      New customer             1
# 5       1.0      New customer             2
# 6       1.0      New customer             2
# 7       1.0      New customer             2
# 8       1.0      New customer             2
# 9       1.0      New customer             2
# 10      1.0      New customer             2
# 11      1.0      New customer             3
# 12      1.0      New customer             3
# 13      1.0      New customer             3
# 14      1.0      New customer             3
# 15      1.0      New customer             3
# 16      1.0      New customer             4
# 17      1.0      New customer             4
# 18      1.0      New customer             4
# 19      1.0      New customer             4
# ...

# %% [markdown]
# # Excercise 4.8..............

# %% [markdown]
# # In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
#Grouping Data with pandas
df_ords_prods_merge.groupby('product_name')
df_ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# They are entirely different. Some are slightly higher now and some are slightly lower. Seems to be a trend towards slightly higher on average.

# %% [markdown]
# # The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
#Grouping Data with pandas
df_ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean']})
# Out:
#                     prices
#                       mean
# loyalty_flag
# Loyal customer    7.772758
# New customer      7.800029
# Regular customer  7.797197

# %% [markdown]
# There is no real difference between the differently loyal customers, all are 7.8 mean price.

# %% [markdown]
# # The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# # If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# # If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
df_ords_prods_merge['mean_spent'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform('mean')

# %%
df_ords_prods_merge.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0             1                   2                  8
# 1  2539329.0      1.0             1                   2                  8
# 2  2539329.0      1.0             1                   2                  8
# 3  2539329.0      1.0             1                   2                  8
# 4  2539329.0      1.0             1                   2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True       196.0                  1
# 1                     NaN          True     14084.0                  2
# 2                     NaN          True     12427.0                  3
# 3                     NaN          True     26088.0                  4
# 4                     NaN          True     26405.0                  5
#
#    reordered  ... department_id prices  merge_indicator    price-range-loc  \
# ...

# %%
df_ords_prods_merge.tail()
# Out:
#            order_id   user_id  order_number  orders_day_of_week  \
# 32404854  2977660.0  206209.0            13                   1
# 32404855  2977660.0  206209.0            13                   1
# 32404856  2977660.0  206209.0            13                   1
# 32404857  2977660.0  206209.0            13                   1
# 32404858  2977660.0  206209.0            13                   1
#
#           order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 32404854                 12                     7.0         False     14197.0
# 32404855                 12                     7.0         False     38730.0
# 32404856                 12                     7.0         False     31477.0
# 32404857                 12                     7.0         False      6567.0
# 32404858                 12                     7.0         False     22920.0
#
#           add_to_cart_order  reordered  ... department_id prices  \
# ...

# %%
#Now need to assign flags to the high/low spenders
df_ords_prods_merge.loc[df_ords_prods_merge['mean_spent'] < 10, 'spender_flag'] = 'Low spender'
df_ords_prods_merge.loc[df_ords_prods_merge['mean_spent'] >= 10, 'spender_flag'] = 'High spender'

# %%
df_ords_prods_merge.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0             1                   2                  8
# 1  2539329.0      1.0             1                   2                  8
# 2  2539329.0      1.0             1                   2                  8
# 3  2539329.0      1.0             1                   2                  8
# 4  2539329.0      1.0             1                   2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True       196.0                  1
# 1                     NaN          True     14084.0                  2
# 2                     NaN          True     12427.0                  3
# 3                     NaN          True     26088.0                  4
# 4                     NaN          True     26405.0                  5
#
#    reordered  ... prices merge_indicator    price-range-loc   Busiest day  \
# ...

# %%
df_ords_prods_merge.value_counts('spender_flag')
# Out:
# spender_flag
# Low spender     32285165
# High spender      119694
# Name: count, dtype: int64

# %% [markdown]
# # In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# # If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# # If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# # If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
#Make a median-days column to work a flag off
df_ords_prods_merge['median_days_s_p_o'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform('median')
df_ords_prods_merge.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0             1                   2                  8
# 1  2539329.0      1.0             1                   2                  8
# 2  2539329.0      1.0             1                   2                  8
# 3  2539329.0      1.0             1                   2                  8
# 4  2539329.0      1.0             1                   2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True       196.0                  1
# 1                     NaN          True     14084.0                  2
# 2                     NaN          True     12427.0                  3
# 3                     NaN          True     26088.0                  4
# 4                     NaN          True     26405.0                  5
#
#    reordered  ... merge_indicator    price-range-loc   Busiest day  \
# ...

# %%
# Median days since prior order = ''median_days_s_p_o'

# %%
df_ords_prods_merge.tail()
# Out:
#            order_id   user_id  order_number  orders_day_of_week  \
# 32404854  2977660.0  206209.0            13                   1
# 32404855  2977660.0  206209.0            13                   1
# 32404856  2977660.0  206209.0            13                   1
# 32404857  2977660.0  206209.0            13                   1
# 32404858  2977660.0  206209.0            13                   1
#
#           order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 32404854                 12                     7.0         False     14197.0
# 32404855                 12                     7.0         False     38730.0
# 32404856                 12                     7.0         False     31477.0
# 32404857                 12                     7.0         False      6567.0
# 32404858                 12                     7.0         False     22920.0
#
#           add_to_cart_order  reordered  ... merge_indicator  \
# ...

# %%
#Now need to assign flags to the regular buyers
df_ords_prods_merge.loc[df_ords_prods_merge['median_days_s_p_o'] <= 10, 'buyer_flag'] = 'Frequent customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['median_days_s_p_o'] > 10) & (df_ords_prods_merge['median_days_s_p_o']<= 20), 'buyer_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['median_days_s_p_o'] > 20, 'buyer_flag'] = 'Non-frequent customer'

# %%
df_ords_prods_merge.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0             1                   2                  8
# 1  2539329.0      1.0             1                   2                  8
# 2  2539329.0      1.0             1                   2                  8
# 3  2539329.0      1.0             1                   2                  8
# 4  2539329.0      1.0             1                   2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True       196.0                  1
# 1                     NaN          True     14084.0                  2
# 2                     NaN          True     12427.0                  3
# 3                     NaN          True     26088.0                  4
# 4                     NaN          True     26405.0                  5
#
#    reordered  ...    price-range-loc   Busiest day    Busiest days  \
# ...

# %%
df_ords_prods_merge.tail()
# Out:
#            order_id   user_id  order_number  orders_day_of_week  \
# 32404854  2977660.0  206209.0            13                   1
# 32404855  2977660.0  206209.0            13                   1
# 32404856  2977660.0  206209.0            13                   1
# 32404857  2977660.0  206209.0            13                   1
# 32404858  2977660.0  206209.0            13                   1
#
#           order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 32404854                 12                     7.0         False     14197.0
# 32404855                 12                     7.0         False     38730.0
# 32404856                 12                     7.0         False     31477.0
# 32404857                 12                     7.0         False      6567.0
# 32404858                 12                     7.0         False     22920.0
#
#           add_to_cart_order  reordered  ...    price-range-loc   Busiest day  \
# ...

# %%
df_ords_prods_merge.value_counts('buyer_flag')
# Out:
# buyer_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# Name: count, dtype: int64

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_E4.8.pkl'))
